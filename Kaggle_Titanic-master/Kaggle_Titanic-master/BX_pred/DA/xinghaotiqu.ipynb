# %%
import pandas as pd

data = pd.read_excel(r'E:\gitlab\Kaggle_Titanic-master\Kaggle_Titanic-master\BX_pred\DA\合并后的数据_去result.xlsx')
data.head(10)
# Out:
# <div>
# <style>
#     .dataframe thead tr:only-child th {
#         text-align: right;
#     }
#
#     .dataframe thead th {
#         text-align: left;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>4. Panel brand: M 品牌</th>
#       <th>Unnamed: 1</th>
#       <th>4. VIB (native product) 型号</th>
#       <th>1. Calendar year / week 年/周</th>
#       <th>PC</th>
#       <th>Unnamed: 5</th>
#       <th>品牌</th>
#       <th>产品</th>
#       <th>产品子类</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>A01</td>
#       <td>Bosch</td>
#       <td>BBH21634CN</td>
#       <td>7.2017</td>
#       <td>16</td>
#       <td>NaN</td>
#       <td>博世</td>
#       <td>生活家电</td>
#       <td>立式吸尘器T14</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>A01</td>
#       <td>Bosch</td>
# ...

# %%
del data['Unnamed: 5']
data.head(10)
# Out:
# <div>
# <style>
#     .dataframe thead tr:only-child th {
#         text-align: right;
#     }
#
#     .dataframe thead th {
#         text-align: left;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>4. Panel brand: M 品牌</th>
#       <th>Unnamed: 1</th>
#       <th>4. VIB (native product) 型号</th>
#       <th>1. Calendar year / week 年/周</th>
#       <th>PC</th>
#       <th>品牌</th>
#       <th>产品</th>
#       <th>产品子类</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>A01</td>
#       <td>Bosch</td>
#       <td>BBH21634CN</td>
#       <td>7.2017</td>
#       <td>16</td>
#       <td>博世</td>
#       <td>生活家电</td>
#       <td>立式吸尘器T14</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>A01</td>
#       <td>Bosch</td>
#       <td>BBH21634CN</td>
#       <td>11.2017</td>
#       <td>1</td>
# ...

# %%
del data['4. Panel brand: M 品牌']
del data['Unnamed: 1']
data.head(10)
# Out:
# <div>
# <style>
#     .dataframe thead tr:only-child th {
#         text-align: right;
#     }
#
#     .dataframe thead th {
#         text-align: left;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>4. VIB (native product) 型号</th>
#       <th>1. Calendar year / week 年/周</th>
#       <th>PC</th>
#       <th>品牌</th>
#       <th>产品</th>
#       <th>产品子类</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>BBH21634CN</td>
#       <td>7.2017</td>
#       <td>16</td>
#       <td>博世</td>
#       <td>生活家电</td>
#       <td>立式吸尘器T14</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>BBH21634CN</td>
#       <td>11.2017</td>
#       <td>1</td>
#       <td>博世</td>
#       <td>生活家电</td>
#       <td>立式吸尘器T14</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>BBH22451CN</td>
# ...

# %%
data=data.rename(columns={'4. VIB (native product) 型号': 'VIB'})
data=data.rename(columns={'1. Calendar year / week 年/周': 'T'})
data.head(10)
# Out:
# <div>
# <style>
#     .dataframe thead tr:only-child th {
#         text-align: right;
#     }
#
#     .dataframe thead th {
#         text-align: left;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>VIB</th>
#       <th>T</th>
#       <th>PC</th>
#       <th>品牌</th>
#       <th>产品</th>
#       <th>产品子类</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>BBH21634CN</td>
#       <td>7.2017</td>
#       <td>16</td>
#       <td>博世</td>
#       <td>生活家电</td>
#       <td>立式吸尘器T14</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>BBH21634CN</td>
#       <td>11.2017</td>
#       <td>1</td>
#       <td>博世</td>
#       <td>生活家电</td>
#       <td>立式吸尘器T14</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>BBH22451CN</td>
#       <td>51.2016</td>
#       <td>2</td>
#       <td>博世</td>
# ...

# %%
data.dtypes
# Out:
# VIB     object
# T       object
# PC       int64
# 品牌      object
# 产品      object
# 产品子类    object
# dtype: object

# %%
data[]
